# %%
import numpy as np
import numpy as np
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.constraints import MaxNorm
from keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)

# load data
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# normalize inputs from 0-255 to 0.0-1.0
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# one hot encode outputs
y_train = to_categorical(y_train) # Use to_categorical directly
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# Create the model
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(32, 32, 3), padding='same', activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same', kernel_constraint=MaxNorm(3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(1024, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu', kernel_constraint=MaxNorm(3)))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# Compile model
epochs = 25
lrate = 0.01
decay = lrate / epochs
sgd = SGD(learning_rate=lrate, momentum=0.9, nesterov=False)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

print(model.summary())

# Fit the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=32)

# Final evaluation of the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))

# Predict the first 4 images of the test data
predictions = model.predict(X_test[:4])
predicted_classes = np.argmax(predictions, axis=1)
actual_classes = np.argmax(y_test[:4], axis=1)

for i in range(4):
    print(f"Image {i+1}: Predicted: {predicted_classes[i]}, Actual: {actual_classes[i]}")

# Visualize the first 4 test images
for i in range(4):
    plt.imshow(X_test[i])
    plt.title(f"Predicted: {predicted_classes[i]}, Actual: {actual_classes[i]}")
    plt.show()

# Visualize Loss and Accuracy
plt.figure(figsize=(12, 4))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_3 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 1024)              2098176
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 2915114 (11.12 MB)
# Trainable params: 2915114 (11.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/25
# 1563/1563 [==============================] - 25s 12ms/step - loss: 1.9062 - accuracy: 0.2975 - val_loss: 1.5406 - val_accuracy: 0.4446
# Epoch 2/25
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.4537 - accuracy: 0.4716 - val_loss: 1.3648 - val_accuracy: 0.5055
# Epoch 3/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.2530 - accuracy: 0.5485 - val_loss: 1.1228 - val_accuracy: 0.6043
# Epoch 4/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 1.0862 - accuracy: 0.6134 - val_loss: 1.0293 - val_accuracy: 0.6374
# Epoch 5/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9705 - accuracy: 0.6591 - val_loss: 0.9216 - val_accuracy: 0.6744
# Epoch 6/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.8749 - accuracy: 0.6928 - val_loss: 0.8352 - val_accuracy: 0.7071
# Epoch 7/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.8136 - accuracy: 0.7154 - val_loss: 0.8378 - val_accuracy: 0.7106
# Epoch 8/25
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7600 - accuracy: 0.7350 - val_loss: 0.7908 - val_accuracy: 0.7236
# Epoch 9/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7196 - accuracy: 0.7473 - val_loss: 0.7684 - val_accuracy: 0.7321
# Epoch 10/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6825 - accuracy: 0.7605 - val_loss: 0.7296 - val_accuracy: 0.7457
# Epoch 11/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6453 - accuracy: 0.7725 - val_loss: 0.7657 - val_accuracy: 0.7376
# Epoch 12/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6320 - accuracy: 0.7798 - val_loss: 0.7319 - val_accuracy: 0.7483
# Epoch 13/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.6072 - accuracy: 0.7876 - val_loss: 0.7153 - val_accuracy: 0.7535
# Epoch 14/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5970 - accuracy: 0.7910 - val_loss: 0.6958 - val_accuracy: 0.7637
# Epoch 15/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.5803 - accuracy: 0.7987 - val_loss: 0.7078 - val_accuracy: 0.7540
# Epoch 16/25
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5630 - accuracy: 0.8033 - val_loss: 0.7540 - val_accuracy: 0.7405
# Epoch 17/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.5515 - accuracy: 0.8075 - val_loss: 0.7384 - val_accuracy: 0.7508
# Epoch 18/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5513 - accuracy: 0.8100 - val_loss: 0.7132 - val_accuracy: 0.7561
# Epoch 19/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5440 - accuracy: 0.8116 - val_loss: 0.7341 - val_accuracy: 0.7552
# Epoch 20/25
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.5391 - accuracy: 0.8141 - val_loss: 0.7722 - val_accuracy: 0.7464
# Epoch 21/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5445 - accuracy: 0.8128 - val_loss: 0.7458 - val_accuracy: 0.7496
# Epoch 22/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5298 - accuracy: 0.8169 - val_loss: 0.7342 - val_accuracy: 0.7528
# Epoch 23/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5421 - accuracy: 0.8129 - val_loss: 0.7461 - val_accuracy: 0.7493
# Epoch 24/25
# 1563/1563 [==============================] - 13s 8ms/step - loss: 0.5388 - accuracy: 0.8159 - val_loss: 0.7671 - val_accuracy: 0.7412
# Epoch 25/25
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.5538 - accuracy: 0.8108 - val_loss: 0.7407 - val_accuracy: 0.7496
# Accuracy: 74.96%
# 1/1 [==============================] - 1s 509ms/step
# Image 1: Predicted: 3, Actual: 3
# Image 2: Predicted: 8, Actual: 8
# Image 3: Predicted: 8, Actual: 8
# Image 4: Predicted: 0, Actual: 0
